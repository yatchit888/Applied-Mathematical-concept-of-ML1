# %% [markdown]
# <p style="font-family: Arial; font-size:3em;color:black;"> Session 5 - Lab Exercise 9</p>

# %% [markdown]
# Group 6:
#
# *  Ahmed Ali
# *  Anuphap Chansatit
# *  Chotiros Srisiam
# *  Halari Shanpru
# *  Karthikeyan Jeyabalasuntharam
# *  Nichapat Boonprasertsri
# *  Vitchaya Siripoppohn
# *  Yat Chit Law

# %%
# For this example, we will use K-Means Clustering Project database from Kaggle (https://www.kaggle.com/faressayah/k-means-clustering-private-vs-public-universities)
# We actually have the labels for this data set, but we will NOT use them for the KMeans clustering algorithm, since that is an unsupervised learning algorithm.
# As we will shortly see, we have a data frame with 777 observations on 18 variables.

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('College_Data.csv',index_col=0)
df.columns
# Out:
# Index(['Private', 'Apps', 'Accept', 'Enroll', 'Top10perc', 'Top25perc',
#        'F.Undergrad', 'P.Undergrad', 'Outstate', 'Room.Board', 'Books',
#        'Personal', 'PhD', 'Terminal', 'S.F.Ratio', 'perc.alumni', 'Expend',
#        'Grad.Rate'],
#       dtype='object')

# %%
df.head(5)
# Out:
#                              Private  Apps  Accept  Enroll  Top10perc  \
# Abilene Christian University     Yes  1660    1232     721         23
# Adelphi University               Yes  2186    1924     512         16
# Adrian College                   Yes  1428    1097     336         22
# Agnes Scott College              Yes   417     349     137         60
# Alaska Pacific University        Yes   193     146      55         16
#
#                               Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# Abilene Christian University         52         2885          537      7440
# Adelphi University                   29         2683         1227     12280
# Adrian College                       50         1036           99     11250
# Agnes Scott College                  89          510           63     12960
# Alaska Pacific University            44          249          869      7560
#
#                               Room.Board  Books  Personal  PhD  Terminal  \
# ...

# %%
df['Grad.Rate']['Cazenovia College'] = 100

# Try removing various columns (features) from the dataset and examin if it improves/degrades your K-Means model performance, or it may have little impact.
# Report 10 cases where you removed one or more features and indicate how it impacted the model performance.
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
from sklearn.cluster import KMeans

# %%
kmeans = KMeans(n_clusters=2)

# %%
kmeans.fit(df.drop('Private',axis=1))   
print(kmeans.cluster_centers_) 
Cluster_predict=kmeans.predict(df.drop('Private',axis=1))
df['Cluster_predict'] = Cluster_predict
df.head(5)
# Out:
# [[1.81323468e+03 1.28716592e+03 4.91044843e+02 2.53094170e+01
#   5.34708520e+01 2.18854858e+03 5.95458894e+02 1.03957085e+04
#   4.31136472e+03 5.41982063e+02 1.28033632e+03 7.04424514e+01
#   7.78251121e+01 1.40997010e+01 2.31748879e+01 8.93204634e+03
#   6.50926756e+01]
#  [1.03631389e+04 6.55089815e+03 2.56972222e+03 4.14907407e+01
#   7.02037037e+01 1.30619352e+04 2.46486111e+03 1.07191759e+04
#   4.64347222e+03 5.95212963e+02 1.71420370e+03 8.63981481e+01
#   9.13333333e+01 1.40277778e+01 2.00740741e+01 1.41705000e+04
#   6.75925926e+01]]
#                              Private  Apps  Accept  Enroll  Top10perc  \
# Abilene Christian University     Yes  1660    1232     721         23
# Adelphi University               Yes  2186    1924     512         16
# Adrian College                   Yes  1428    1097     336         22
# Agnes Scott College              Yes   417     349     137         60
# Alaska Pacific University        Yes   193     146      55         16
#
# ...

# %%
def convert_to_binary(cluster):  # converts labels for Private into binary values of 0 and 1
    if cluster=='Yes':
        return 1
    else:
        return 0

# %%
df['Cluster_actual'] = df['Private'].apply(convert_to_binary)

# %%
from sklearn.metrics import confusion_matrix
print("Removing Private : ")
print(confusion_matrix(df['Cluster_actual'],kmeans.labels_))
# Out:
# Removing Private :
# [[138  74]
#  [531  34]]

# %%
kmeans.fit(df.drop(['Private','Accept'],axis=1))    # we will not (and shall not) use class info, it is available only because this is an exercise and we want to examine the perofmacne of our K-Means algorithm.
print(kmeans.cluster_centers_) # returns the values of the centroids
Cluster_predict=kmeans.predict(df.drop(['Private','Accept'],axis=1))
df['Cluster_predict'] = Cluster_predict
df.head(50)
# Out:
# [[1.05324369e+04 2.60870874e+03 4.22621359e+01 7.04854369e+01
#   1.32799515e+04 2.51251456e+03 1.07732233e+04 4.65533010e+03
#   5.97932039e+02 1.73386408e+03 8.66796117e+01 9.14660194e+01
#   1.39233010e+01 2.01456311e+01 1.44687282e+04 6.73786408e+01
#   1.00000000e+00 3.00970874e-01]
#  [1.85078932e+03 5.00507418e+02 2.53115727e+01 5.35519288e+01
#   2.23589466e+03 6.02044510e+02 1.03898487e+04 4.31201632e+03
#   5.41961424e+02 1.28055045e+03 7.05178042e+01 7.79050445e+01
#   1.41151335e+01 2.31409496e+01 8.92533234e+03 6.51439169e+01
#   7.41839763e-03 7.92284866e-01]]
#                                         Private   Apps  Accept  Enroll  \
# Abilene Christian University                Yes   1660    1232     721
# Adelphi University                          Yes   2186    1924     512
# Adrian College                              Yes   1428    1097     336
# Agnes Scott College                         Yes    417     349     137
# ...

# %%
from sklearn.metrics import confusion_matrix
print("Removing Private and Accept")
print(confusion_matrix(df['Cluster_actual'],kmeans.labels_))
# Out:
# Removing Private and Accept
# [[ 72 140]
#  [ 31 534]]

# %%
#Removing Acceptcolumn degrades the performance of the model

# %%
kmeans.fit(df.drop(['Private','Apps'],axis=1))    # we will not (and shall not) use class info, it is available only because this is an exercise and we want to examine the perofmacne of our K-Means algorithm.
print(kmeans.cluster_centers_) # returns the values of the centroids
Cluster_predict=kmeans.predict(df.drop(['Private','Apps'],axis=1))
df['Cluster_predict'] = Cluster_predict
df.head(50)
# Out:
# [[2.22874342e+03 7.05888158e+02 4.84539474e+01 7.60328947e+01
#   2.83048026e+03 2.64500000e+02 1.65966513e+04 5.38750658e+03
#   5.65164474e+02 1.02571053e+03 8.68486842e+01 9.27960526e+01
#   1.05427632e+01 3.44276316e+01 1.69804408e+04 7.91907895e+01
#   7.96052632e-01 9.80263158e-01]
#  [1.96774720e+03 7.97990400e+02 2.24768000e+01 5.08752000e+01
#   3.91135200e+03 9.98980800e+02 8.94353440e+03 4.10703520e+03
#   5.45542400e+02 1.41723360e+03 6.92096000e+01 7.65184000e+01
#   1.49523200e+01 1.99024000e+01 7.87988160e+03 6.20960000e+01
#   8.84800000e-01 6.65600000e-01]]
#                                         Private   Apps  Accept  Enroll  \
# Abilene Christian University                Yes   1660    1232     721
# Adelphi University                          Yes   2186    1924     512
# Adrian College                              Yes   1428    1097     336
# Agnes Scott College                         Yes    417     349     137
# ...

# %%
from sklearn.metrics import confusion_matrix
print("Removing Private and Apps")
print(confusion_matrix(df['Cluster_actual'],kmeans.labels_))
# Out:
# Removing Private and Apps
# [[  3 209]
#  [149 416]]

# %%
#Removing Apps column heavily degrades the performance of the model

# %%
kmeans.fit(df.drop(['Private','Enroll'],axis=1))    # we will not (and shall not) use class info, it is available only because this is an exercise and we want to examine the perofmacne of our K-Means algorithm.
print(kmeans.cluster_centers_) # returns the values of the centroids
Cluster_predict=kmeans.predict(df.drop(['Private','Enroll'],axis=1))
df['Cluster_predict'] = Cluster_predict
df.head(50)
# Out:
# [[1.81323468e+03 1.28716592e+03 2.53094170e+01 5.34708520e+01
#   2.18854858e+03 5.95458894e+02 1.03957085e+04 4.31136472e+03
#   5.41982063e+02 1.28033632e+03 7.04424514e+01 7.78251121e+01
#   1.40997010e+01 2.31748879e+01 8.93204634e+03 6.50926756e+01
#   8.20627803e-01 7.93721973e-01]
#  [1.03631389e+04 6.55089815e+03 4.14907407e+01 7.02037037e+01
#   1.30619352e+04 2.46486111e+03 1.07191759e+04 4.64347222e+03
#   5.95212963e+02 1.71420370e+03 8.63981481e+01 9.13333333e+01
#   1.40277778e+01 2.00740741e+01 1.41705000e+04 6.75925926e+01
#   7.03703704e-01 3.14814815e-01]]
#                                         Private   Apps  Accept  Enroll  \
# Abilene Christian University                Yes   1660    1232     721
# Adelphi University                          Yes   2186    1924     512
# Adrian College                              Yes   1428    1097     336
# Agnes Scott College                         Yes    417     349     137
# ...

# %%
from sklearn.metrics import confusion_matrix
print("Removing Enroll")
print(confusion_matrix(df['Cluster_actual'],kmeans.labels_))
# Out:
# Removing Enroll
# [[138  74]
#  [531  34]]

# %%
#Removing the Enroll column doesn't have any impact on the performance of the model

# %%
kmeans.fit(df.drop(['Private','Top10perc'],axis=1))    # we will not (and shall not) use class info, it is available only because this is an exercise and we want to examine the perofmacne of our K-Means algorithm.
print(kmeans.cluster_centers_) # returns the values of the centroids
Cluster_predict=kmeans.predict(df.drop(['Private','Top10perc'],axis=1))
df['Cluster_predict'] = Cluster_predict
df.head(50)
# Out:
# [[1.81323468e+03 1.28716592e+03 4.91044843e+02 5.34708520e+01
#   2.18854858e+03 5.95458894e+02 1.03957085e+04 4.31136472e+03
#   5.41982063e+02 1.28033632e+03 7.04424514e+01 7.78251121e+01
#   1.40997010e+01 2.31748879e+01 8.93204634e+03 6.50926756e+01
#   3.88578059e-16 7.93721973e-01]
#  [1.03631389e+04 6.55089815e+03 2.56972222e+03 7.02037037e+01
#   1.30619352e+04 2.46486111e+03 1.07191759e+04 4.64347222e+03
#   5.95212963e+02 1.71420370e+03 8.63981481e+01 9.13333333e+01
#   1.40277778e+01 2.00740741e+01 1.41705000e+04 6.75925926e+01
#   1.00000000e+00 3.14814815e-01]]
#                                         Private   Apps  Accept  Enroll  \
# Abilene Christian University                Yes   1660    1232     721
# Adelphi University                          Yes   2186    1924     512
# Adrian College                              Yes   1428    1097     336
# Agnes Scott College                         Yes    417     349     137
# ...

# %%
from sklearn.metrics import confusion_matrix
print("Removing Top10perc")
print(confusion_matrix(df['Cluster_actual'],kmeans.labels_))
# Out:
# Removing Top10perc
# [[138  74]
#  [531  34]]

# %%
#Removing the Top10perc column doesn't have any impact on the performance of the model

# %%
kmeans.fit(df.drop(['Private','Top25perc'],axis=1))    # we will not (and shall not) use class info, it is available only because this is an exercise and we want to examine the perofmacne of our K-Means algorithm.
print(kmeans.cluster_centers_) # returns the values of the centroids
Cluster_predict=kmeans.predict(df.drop(['Private','Top25perc'],axis=1))
df['Cluster_predict'] = Cluster_predict
df.head(50)
# Out:
# [[1.81323468e+03 1.28716592e+03 4.91044843e+02 2.53094170e+01
#   2.18854858e+03 5.95458894e+02 1.03957085e+04 4.31136472e+03
#   5.41982063e+02 1.28033632e+03 7.04424514e+01 7.78251121e+01
#   1.40997010e+01 2.31748879e+01 8.93204634e+03 6.50926756e+01
#   3.88578059e-16 7.93721973e-01]
#  [1.03631389e+04 6.55089815e+03 2.56972222e+03 4.14907407e+01
#   1.30619352e+04 2.46486111e+03 1.07191759e+04 4.64347222e+03
#   5.95212963e+02 1.71420370e+03 8.63981481e+01 9.13333333e+01
#   1.40277778e+01 2.00740741e+01 1.41705000e+04 6.75925926e+01
#   1.00000000e+00 3.14814815e-01]]
#                                         Private   Apps  Accept  Enroll  \
# Abilene Christian University                Yes   1660    1232     721
# Adelphi University                          Yes   2186    1924     512
# Adrian College                              Yes   1428    1097     336
# Agnes Scott College                         Yes    417     349     137
# ...

# %%
from sklearn.metrics import confusion_matrix
print("Removing Top25perc")
print(confusion_matrix(df['Cluster_actual'],kmeans.labels_))
# Out:
# Removing Top25perc
# [[138  74]
#  [531  34]]

# %%
#Removing the Top25perc column doesn't have any impact on the model

# %%
kmeans.fit(df.drop(['Private','F.Undergrad'],axis=1))    # we will not (and shall not) use class info, it is available only because this is an exercise and we want to examine the perofmacne of our K-Means algorithm.
print(kmeans.cluster_centers_) # returns the values of the centroids
Cluster_predict=kmeans.predict(df.drop(['Private','F.Undergrad'],axis=1))
df['Cluster_predict'] = Cluster_predict
df.head(50)
# Out:
# [[2.27269968e+03 1.64662987e+03 6.85485390e+02 2.23750000e+01
#   5.06347403e+01 8.74996753e+02 9.04055357e+03 4.10016721e+03
#   5.42170455e+02 1.39076623e+03 6.89042208e+01 7.62678571e+01
#   1.49392857e+01 2.04707792e+01 7.80917695e+03 6.21509740e+01
#   8.76623377e-02 6.93181818e-01]
#  [5.79062112e+03 3.44277640e+03 1.14149068e+03 4.73913043e+01
#   7.55465839e+01 7.79931677e+02 1.57976335e+04 5.34220497e+03
#   5.76968944e+02 1.14886335e+03 8.70310559e+01 9.28447205e+01
#   1.08391304e+01 3.14409938e+01 1.67422360e+04 7.80248447e+01
#   3.35403727e-01 8.57142857e-01]]
#                                         Private   Apps  Accept  Enroll  \
# Abilene Christian University                Yes   1660    1232     721
# Adelphi University                          Yes   2186    1924     512
# Adrian College                              Yes   1428    1097     336
# Agnes Scott College                         Yes    417     349     137
# ...

# %%
from sklearn.metrics import confusion_matrix
print("Removing F.Undergrad")
print(confusion_matrix(df['Cluster_actual'],kmeans.labels_))
# Out:
# Removing F.Undergrad
# [[189  23]
#  [427 138]]

# %%
#Removing the F.Undergrad improved the performance of the model

# %%
kmeans.fit(df.drop(['Private','P.Undergrad'],axis=1))    # we will not (and shall not) use class info, it is available only because this is an exercise and we want to examine the perofmacne of our K-Means algorithm.
print(kmeans.cluster_centers_) # returns the values of the centroids
Cluster_predict=kmeans.predict(df.drop(['Private','P.Undergrad'],axis=1))
df['Cluster_predict'] = Cluster_predict
df.head(50)
# Out:
# [[1.82359762e+03 1.29450373e+03 4.94876304e+02 2.52861401e+01
#   5.34530551e+01 2.21174665e+03 1.03852712e+04 4.30851267e+03
#   5.42050671e+02 1.28298808e+03 7.04754098e+01 7.78658718e+01
#   1.40992548e+01 2.31520119e+01 8.92991505e+03 6.50372578e+01
#   1.59463487e-01 7.91356185e-01]
#  [1.04588585e+04 6.60376415e+03 2.58468868e+03 4.19433962e+01
#   7.06320755e+01 1.31202453e+04 1.07913491e+04 4.66779245e+03
#   5.95783019e+02 1.70560377e+03 8.64905660e+01 9.13301887e+01
#   1.40292453e+01 2.01603774e+01 1.42828302e+04 6.79905660e+01
#   5.09433962e-01 3.20754717e-01]]
#                                         Private   Apps  Accept  Enroll  \
# Abilene Christian University                Yes   1660    1232     721
# Adelphi University                          Yes   2186    1924     512
# Adrian College                              Yes   1428    1097     336
# Agnes Scott College                         Yes    417     349     137
# ...

# %%
from sklearn.metrics import confusion_matrix
print("Removing P.Undergrad")
print(confusion_matrix(df['Cluster_actual'],kmeans.labels_))
# Out:
# Removing P.Undergrad
# [[140  72]
#  [531  34]]

# %%
#Removing the P.Undergrad model also slightly increased the performance of the model

# %%
kmeans.fit(df.drop(['Private','Outstate'],axis=1))    # we will not (and shall not) use class info, it is available only because this is an exercise and we want to examine the perofmacne of our K-Means algorithm.
print(kmeans.cluster_centers_) # returns the values of the centroids
Cluster_predict=kmeans.predict(df.drop(['Private','Outstate'],axis=1))
df['Cluster_predict'] = Cluster_predict
df.head(50)
# Out:
# [[ 1.81323468e+03  1.28716592e+03  4.91044843e+02  2.53094170e+01
#    5.34708520e+01  2.18854858e+03  5.95458894e+02  4.31136472e+03
#    5.41982063e+02  1.28033632e+03  7.04424514e+01  7.78251121e+01
#    1.40997010e+01  2.31748879e+01  8.93204634e+03  6.50926756e+01
#   -5.27355937e-16  7.93721973e-01]
#  [ 1.03631389e+04  6.55089815e+03  2.56972222e+03  4.14907407e+01
#    7.02037037e+01  1.30619352e+04  2.46486111e+03  4.64347222e+03
#    5.95212963e+02  1.71420370e+03  8.63981481e+01  9.13333333e+01
#    1.40277778e+01  2.00740741e+01  1.41705000e+04  6.75925926e+01
#    9.81481481e-01  3.14814815e-01]]
#                                         Private   Apps  Accept  Enroll  \
# Abilene Christian University                Yes   1660    1232     721
# Adelphi University                          Yes   2186    1924     512
# Adrian College                              Yes   1428    1097     336
# Agnes Scott College                         Yes    417     349     137
# ...

# %%
from sklearn.metrics import confusion_matrix
print("Removing Outstate")
print(confusion_matrix(df['Cluster_actual'],kmeans.labels_))
# Out:
# Removing Outstate
# [[138  74]
#  [531  34]]

# %%
#Removing Outstate doesn't have any impact on the model

# %%
kmeans.fit(df.drop(['Private','Personal'],axis=1))    # we will not (and shall not) use class info, it is available only because this is an exercise and we want to examine the perofmacne of our K-Means algorithm.
print(kmeans.cluster_centers_) # returns the values of the centroids
Cluster_predict=kmeans.predict(df.drop(['Private','Personal'],axis=1))
df['Cluster_predict'] = Cluster_predict
df.head(50)
# Out:
# [[1.81323468e+03 1.28716592e+03 4.91044843e+02 2.53094170e+01
#   5.34708520e+01 2.18854858e+03 5.95458894e+02 1.03957085e+04
#   4.31136472e+03 5.41982063e+02 7.04424514e+01 7.78251121e+01
#   1.40997010e+01 2.31748879e+01 8.93204634e+03 6.50926756e+01
#   3.88578059e-16 7.93721973e-01]
#  [1.03631389e+04 6.55089815e+03 2.56972222e+03 4.14907407e+01
#   7.02037037e+01 1.30619352e+04 2.46486111e+03 1.07191759e+04
#   4.64347222e+03 5.95212963e+02 8.63981481e+01 9.13333333e+01
#   1.40277778e+01 2.00740741e+01 1.41705000e+04 6.75925926e+01
#   1.00000000e+00 3.14814815e-01]]
#                                         Private   Apps  Accept  Enroll  \
# Abilene Christian University                Yes   1660    1232     721
# Adelphi University                          Yes   2186    1924     512
# Adrian College                              Yes   1428    1097     336
# Agnes Scott College                         Yes    417     349     137
# ...

# %%
from sklearn.metrics import confusion_matrix
print("Removing Personal")
print(confusion_matrix(df['Cluster_actual'],kmeans.labels_))
# Out:
# Removing Personal
# [[138  74]
#  [531  34]]

# %%
#Removing Personal also doesn't have any impact on the performance of the model

# %%
kmeans.fit(df.drop(['Private','PhD'],axis=1))    # we will not (and shall not) use class info, it is available only because this is an exercise and we want to examine the perofmacne of our K-Means algorithm.
print(kmeans.cluster_centers_) # returns the values of the centroids
Cluster_predict=kmeans.predict(df.drop(['Private','PhD'],axis=1))
df['Cluster_predict'] = Cluster_predict
df.head(50)
# Out:
# [[1.03631389e+04 6.55089815e+03 2.56972222e+03 4.14907407e+01
#   7.02037037e+01 1.30619352e+04 2.46486111e+03 1.07191759e+04
#   4.64347222e+03 5.95212963e+02 1.71420370e+03 9.13333333e+01
#   1.40277778e+01 2.00740741e+01 1.41705000e+04 6.75925926e+01
#   1.00000000e+00 3.14814815e-01]
#  [1.81323468e+03 1.28716592e+03 4.91044843e+02 2.53094170e+01
#   5.34708520e+01 2.18854858e+03 5.95458894e+02 1.03957085e+04
#   4.31136472e+03 5.41982063e+02 1.28033632e+03 7.78251121e+01
#   1.40997010e+01 2.31748879e+01 8.93204634e+03 6.50926756e+01
#   3.88578059e-16 7.93721973e-01]]
#                                         Private   Apps  Accept  Enroll  \
# Abilene Christian University                Yes   1660    1232     721
# Adelphi University                          Yes   2186    1924     512
# Adrian College                              Yes   1428    1097     336
# Agnes Scott College                         Yes    417     349     137
# ...

# %%
from sklearn.metrics import confusion_matrix
print("Removing PhD")
print(confusion_matrix(df['Cluster_actual'],kmeans.labels_))
# Out:
# Removing PhD
# [[ 74 138]
#  [ 34 531]]

# %%
#Removing PhD column degrades the performance of the model

# %%
kmeans.fit(df.drop(['Private','Terminal'],axis=1))    # we will not (and shall not) use class info, it is available only because this is an exercise and we want to examine the perofmacne of our K-Means algorithm.
print(kmeans.cluster_centers_) # returns the values of the centroids
Cluster_predict=kmeans.predict(df.drop(['Private','Terminal'],axis=1))
df['Cluster_predict'] = Cluster_predict
df.head(50)
# Out:
# [[1.03631389e+04 6.55089815e+03 2.56972222e+03 4.14907407e+01
#   7.02037037e+01 1.30619352e+04 2.46486111e+03 1.07191759e+04
#   4.64347222e+03 5.95212963e+02 1.71420370e+03 8.63981481e+01
#   1.40277778e+01 2.00740741e+01 1.41705000e+04 6.75925926e+01
#   2.22044605e-16 3.14814815e-01]
#  [1.81323468e+03 1.28716592e+03 4.91044843e+02 2.53094170e+01
#   5.34708520e+01 2.18854858e+03 5.95458894e+02 1.03957085e+04
#   4.31136472e+03 5.41982063e+02 1.28033632e+03 7.04424514e+01
#   1.40997010e+01 2.31748879e+01 8.93204634e+03 6.50926756e+01
#   1.00000000e+00 7.93721973e-01]]
#                                         Private   Apps  Accept  Enroll  \
# Abilene Christian University                Yes   1660    1232     721
# Adelphi University                          Yes   2186    1924     512
# Adrian College                              Yes   1428    1097     336
# Agnes Scott College                         Yes    417     349     137
# ...

# %%
from sklearn.metrics import confusion_matrix
print("Removing Terminal")
print(confusion_matrix(df['Cluster_actual'],kmeans.labels_))
# Out:
# Removing Terminal
# [[ 74 138]
#  [ 34 531]]

# %%
#Removing the Terminal column also degrades the performance of the model

# %%
kmeans.fit(df.drop(['Private','Room.Board'],axis=1))    # we will not (and shall not) use class info, it is available only because this is an exercise and we want to examine the perofmacne of our K-Means algorithm.
print(kmeans.cluster_centers_) # returns the values of the centroids
Cluster_predict=kmeans.predict(df.drop(['Private','Room.Board'],axis=1))
df['Cluster_predict'] = Cluster_predict
df.head(50)
# Out:
# [[1.81323468e+03 1.28716592e+03 4.91044843e+02 2.53094170e+01
#   5.34708520e+01 2.18854858e+03 5.95458894e+02 1.03957085e+04
#   5.41982063e+02 1.28033632e+03 7.04424514e+01 7.78251121e+01
#   1.40997010e+01 2.31748879e+01 8.93204634e+03 6.50926756e+01
#   1.00000000e+00 7.93721973e-01]
#  [1.03631389e+04 6.55089815e+03 2.56972222e+03 4.14907407e+01
#   7.02037037e+01 1.30619352e+04 2.46486111e+03 1.07191759e+04
#   5.95212963e+02 1.71420370e+03 8.63981481e+01 9.13333333e+01
#   1.40277778e+01 2.00740741e+01 1.41705000e+04 6.75925926e+01
#   2.22044605e-16 3.14814815e-01]]
#                                         Private   Apps  Accept  Enroll  \
# Abilene Christian University                Yes   1660    1232     721
# Adelphi University                          Yes   2186    1924     512
# Adrian College                              Yes   1428    1097     336
# Agnes Scott College                         Yes    417     349     137
# ...

# %%
from sklearn.metrics import confusion_matrix
print("Removing Room.Board")
print(confusion_matrix(df['Cluster_actual'],kmeans.labels_))
# Out:
# Removing Room.Board
# [[138  74]
#  [531  34]]

# %%
#Removing the Room.Board column doesn't have any impact on the perforamnce of the model

# %%
kmeans.fit(df.drop(['Private','S.F.Ratio'],axis=1))    # we will not (and shall not) use class info, it is available only because this is an exercise and we want to examine the perofmacne of our K-Means algorithm.
print(kmeans.cluster_centers_) # returns the values of the centroids
Cluster_predict=kmeans.predict(df.drop(['Private','S.F.Ratio'],axis=1))
df['Cluster_predict'] = Cluster_predict
df.head(50)
# Out:
# [[1.03631389e+04 6.55089815e+03 2.56972222e+03 4.14907407e+01
#   7.02037037e+01 1.30619352e+04 2.46486111e+03 1.07191759e+04
#   4.64347222e+03 5.95212963e+02 1.71420370e+03 8.63981481e+01
#   9.13333333e+01 2.00740741e+01 1.41705000e+04 6.75925926e+01
#   1.00000000e+00 3.14814815e-01]
#  [1.81323468e+03 1.28716592e+03 4.91044843e+02 2.53094170e+01
#   5.34708520e+01 2.18854858e+03 5.95458894e+02 1.03957085e+04
#   4.31136472e+03 5.41982063e+02 1.28033632e+03 7.04424514e+01
#   7.78251121e+01 2.31748879e+01 8.93204634e+03 6.50926756e+01
#   3.88578059e-16 7.93721973e-01]]
#                                         Private   Apps  Accept  Enroll  \
# Abilene Christian University                Yes   1660    1232     721
# Adelphi University                          Yes   2186    1924     512
# Adrian College                              Yes   1428    1097     336
# Agnes Scott College                         Yes    417     349     137
# ...

# %%
from sklearn.metrics import confusion_matrix
print("Removing S.F.Ratio")
print(confusion_matrix(df['Cluster_actual'],kmeans.labels_))
# Out:
# Removing S.F.Ratio
# [[ 74 138]
#  [ 34 531]]

# %%
#Removing the S.F.Ration column degrades the performance of the model

# %%
kmeans.fit(df.drop(['Private','perc.alumni'],axis=1))    # we will not (and shall not) use class info, it is available only because this is an exercise and we want to examine the perofmacne of our K-Means algorithm.
print(kmeans.cluster_centers_) # returns the values of the centroids
Cluster_predict=kmeans.predict(df.drop(['Private','perc.alumni'],axis=1))
df['Cluster_predict'] = Cluster_predict
df.head(50)
# Out:
# [[1.03631389e+04 6.55089815e+03 2.56972222e+03 4.14907407e+01
#   7.02037037e+01 1.30619352e+04 2.46486111e+03 1.07191759e+04
#   4.64347222e+03 5.95212963e+02 1.71420370e+03 8.63981481e+01
#   9.13333333e+01 1.40277778e+01 1.41705000e+04 6.75925926e+01
#   2.22044605e-16 3.14814815e-01]
#  [1.81323468e+03 1.28716592e+03 4.91044843e+02 2.53094170e+01
#   5.34708520e+01 2.18854858e+03 5.95458894e+02 1.03957085e+04
#   4.31136472e+03 5.41982063e+02 1.28033632e+03 7.04424514e+01
#   7.78251121e+01 1.40997010e+01 8.93204634e+03 6.50926756e+01
#   1.00000000e+00 7.93721973e-01]]
#                                         Private   Apps  Accept  Enroll  \
# Abilene Christian University                Yes   1660    1232     721
# Adelphi University                          Yes   2186    1924     512
# Adrian College                              Yes   1428    1097     336
# Agnes Scott College                         Yes    417     349     137
# ...

# %%
from sklearn.metrics import confusion_matrix
print("Removing perc.alumni")
print(confusion_matrix(df['Cluster_actual'],kmeans.labels_))
# Out:
# Removing perc.alumni
# [[ 74 138]
#  [ 34 531]]

# %%
#Removing the perc.alumni column degrades the performance of the model

# %%
kmeans.fit(df.drop(['Private','Expend'],axis=1))    # we will not (and shall not) use class info, it is available only because this is an exercise and we want to examine the perofmacne of our K-Means algorithm.
print(kmeans.cluster_centers_) # returns the values of the centroids
Cluster_predict=kmeans.predict(df.drop(['Private','Expend'],axis=1))
df['Cluster_predict'] = Cluster_predict
df.head(50)
# Out:
# [[1.94209644e+03 1.30753561e+03 4.83994065e+02 2.68011869e+01
#   5.46528190e+01 2.09851335e+03 5.40252226e+02 1.07367211e+04
#   4.38335905e+03 5.44848665e+02 1.26179228e+03 7.10504451e+01
#   7.83115727e+01 1.37627596e+01 2.37551929e+01 6.60103858e+01
#   9.67359050e-01 8.20474777e-01]
#  [9.93495146e+03 6.67312621e+03 2.71676699e+03 3.25145631e+01
#   6.32815534e+01 1.41789320e+04 2.91686408e+03 8.50339806e+03
#   4.18848544e+03 5.79038835e+02 1.85661165e+03 8.31941748e+01
#   8.88058252e+01 1.62291262e+01 1.61262136e+01 6.17087379e+01
#   1.65048544e-01 1.16504854e-01]]
#                                         Private   Apps  Accept  Enroll  \
# Abilene Christian University                Yes   1660    1232     721
# Adelphi University                          Yes   2186    1924     512
# Adrian College                              Yes   1428    1097     336
# Agnes Scott College                         Yes    417     349     137
# ...

# %%
from sklearn.metrics import confusion_matrix
print("Removing Expend")
print(confusion_matrix(df['Cluster_actual'],kmeans.labels_))
# Out:
# Removing Expend
# [[121  91]
#  [553  12]]

# %%
#Removing the Expend column also slightly degrades the performance of the model

# %%
kmeans.fit(df.drop(['Private','Grad.Rate'],axis=1))    # we will not (and shall not) use class info, it is available only because this is an exercise and we want to examine the perofmacne of our K-Means algorithm.
print(kmeans.cluster_centers_) # returns the values of the centroids
Cluster_predict=kmeans.predict(df.drop(['Private','Grad.Rate'],axis=1))
df['Cluster_predict'] = Cluster_predict
df.head(50)
# Out:
# [[1.81323468e+03 1.28716592e+03 4.91044843e+02 2.53094170e+01
#   5.34708520e+01 2.18854858e+03 5.95458894e+02 1.03957085e+04
#   4.31136472e+03 5.41982063e+02 1.28033632e+03 7.04424514e+01
#   7.78251121e+01 1.40997010e+01 2.31748879e+01 8.93204634e+03
#   2.54110613e-02 7.93721973e-01]
#  [1.03631389e+04 6.55089815e+03 2.56972222e+03 4.14907407e+01
#   7.02037037e+01 1.30619352e+04 2.46486111e+03 1.07191759e+04
#   4.64347222e+03 5.95212963e+02 1.71420370e+03 8.63981481e+01
#   9.13333333e+01 1.40277778e+01 2.00740741e+01 1.41705000e+04
#   7.96296296e-01 3.14814815e-01]]
#                                         Private   Apps  Accept  Enroll  \
# Abilene Christian University                Yes   1660    1232     721
# Adelphi University                          Yes   2186    1924     512
# Adrian College                              Yes   1428    1097     336
# Agnes Scott College                         Yes    417     349     137
# ...

# %%
from sklearn.metrics import confusion_matrix
print("Removing Grad.Rate")
print(confusion_matrix(df['Cluster_actual'],kmeans.labels_))
# Out:
# Removing Grad.Rate
# [[138  74]
#  [531  34]]

# %%
#Removing the Grad.Rate column doesn't have any impact on the model

# %%
kmeans.fit(df.drop(['Private','F.Undergrad','P.Undergrad'],axis=1))    # we will not (and shall not) use class info, it is available only because this is an exercise and we want to examine the perofmacne of our K-Means algorithm.
print(kmeans.cluster_centers_) # returns the values of the centroids
Cluster_predict=kmeans.predict(df.drop(['Private','F.Undergrad','P.Undergrad'],axis=1))
df['Cluster_predict'] = Cluster_predict
df.head(50)
# Out:
# [[2.27057561e+03 1.64449593e+03 6.85188618e+02 2.23707317e+01
#   5.06276423e+01 9.03655447e+03 4.09816748e+03 5.41913821e+02
#   1.38977561e+03 6.88634146e+01 7.62373984e+01 1.49534959e+01
#   2.04796748e+01 7.80072195e+03 6.21463415e+01 8.78048780e-02
#   6.92682927e-01]
#  [5.77696914e+03 3.43979012e+03 1.13980247e+03 4.72530864e+01
#   7.54197531e+01 1.57711049e+04 5.34212963e+03 5.77728395e+02
#   1.15411728e+03 8.70740741e+01 9.28580247e+01 1.08104938e+01
#   3.13395062e+01 1.67191914e+04 7.79444444e+01 3.33333333e-01
#   8.58024691e-01]]
#                                         Private   Apps  Accept  Enroll  \
# Abilene Christian University                Yes   1660    1232     721
# Adelphi University                          Yes   2186    1924     512
# Adrian College                              Yes   1428    1097     336
# Agnes Scott College                         Yes    417     349     137
# Alaska Pacific University                   Yes    193     146      55
# ...

# %%
from sklearn.metrics import confusion_matrix
print("Removing F.Undergrad and P.Undergrad")
print(confusion_matrix(df['Cluster_actual'],kmeans.labels_))
# Out:
# Removing F.Undergrad and P.Undergrad
# [[189  23]
#  [426 139]]

# %%
#Removing the F.Undergrad and P.Undergrad improves the performance of the model

# %%
kmeans.fit(df.drop(['Private','Accept','Apps'],axis=1))    # we will not (and shall not) use class info, it is available only because this is an exercise and we want to examine the perofmacne of our K-Means algorithm.
print(kmeans.cluster_centers_) # returns the values of the centroids
Cluster_predict=kmeans.predict(df.drop(['Private','Accept','Apps'],axis=1))
df['Cluster_predict'] = Cluster_predict
df.head(50)
# Out:
# [[7.05888158e+02 4.84539474e+01 7.60328947e+01 2.83048026e+03
#   2.64500000e+02 1.65966513e+04 5.38750658e+03 5.65164474e+02
#   1.02571053e+03 8.68486842e+01 9.27960526e+01 1.05427632e+01
#   3.44276316e+01 1.69804408e+04 7.91907895e+01 8.94736842e-01
#   9.80263158e-01]
#  [7.97990400e+02 2.24768000e+01 5.08752000e+01 3.91135200e+03
#   9.98980800e+02 8.94353440e+03 4.10703520e+03 5.45542400e+02
#   1.41723360e+03 6.92096000e+01 7.65184000e+01 1.49523200e+01
#   1.99024000e+01 7.87988160e+03 6.20960000e+01 4.16000000e-02
#   6.65600000e-01]]
#                                         Private   Apps  Accept  Enroll  \
# Abilene Christian University                Yes   1660    1232     721
# Adelphi University                          Yes   2186    1924     512
# Adrian College                              Yes   1428    1097     336
# Agnes Scott College                         Yes    417     349     137
# Alaska Pacific University                   Yes    193     146      55
# ...

# %%
from sklearn.metrics import confusion_matrix
print("Removing Accept and Apps")
print(confusion_matrix(df['Cluster_actual'],kmeans.labels_))
# Out:
# Removing Accept and Apps
# [[  3 209]
#  [149 416]]

# %%
#Removing Accept and Apps degrades the performance of the model.

# %%
kmeans.fit(df.drop(['Private','PhD','Terminal'],axis=1))    # we will not (and shall not) use class info, it is available only because this is an exercise and we want to examine the perofmacne of our K-Means algorithm.
print(kmeans.cluster_centers_) # returns the values of the centroids
Cluster_predict=kmeans.predict(df.drop(['Private','PhD','Terminal'],axis=1))
df['Cluster_predict'] = Cluster_predict
df.head(50)
# Out:
# [[1.03631389e+04 6.55089815e+03 2.56972222e+03 4.14907407e+01
#   7.02037037e+01 1.30619352e+04 2.46486111e+03 1.07191759e+04
#   4.64347222e+03 5.95212963e+02 1.71420370e+03 1.40277778e+01
#   2.00740741e+01 1.41705000e+04 6.75925926e+01 7.03703704e-01
#   3.14814815e-01]
#  [1.81323468e+03 1.28716592e+03 4.91044843e+02 2.53094170e+01
#   5.34708520e+01 2.18854858e+03 5.95458894e+02 1.03957085e+04
#   4.31136472e+03 5.41982063e+02 1.28033632e+03 1.40997010e+01
#   2.31748879e+01 8.93204634e+03 6.50926756e+01 8.20627803e-01
#   7.93721973e-01]]
#                                         Private   Apps  Accept  Enroll  \
# Abilene Christian University                Yes   1660    1232     721
# Adelphi University                          Yes   2186    1924     512
# Adrian College                              Yes   1428    1097     336
# Agnes Scott College                         Yes    417     349     137
# Alaska Pacific University                   Yes    193     146      55
# ...

# %%
from sklearn.metrics import confusion_matrix
print("Removing PhD and Terminal")
print(confusion_matrix(df['Cluster_actual'],kmeans.labels_))
# Out:
# Removing PhD and Terminal
# [[ 74 138]
#  [ 34 531]]

# %%
#Removing PhD and Terminal degrades the performance of the model

# %%
kmeans.fit(df.drop(['Private','P.Undergrad','PhD'],axis=1))    # we will not (and shall not) use class info, it is available only because this is an exercise and we want to examine the perofmacne of our K-Means algorithm.
print(kmeans.cluster_centers_) # returns the values of the centroids
Cluster_predict=kmeans.predict(df.drop(['Private','P.Undergrad','PhD'],axis=1))
df['Cluster_predict'] = Cluster_predict
df.head(50)
# Out:
# [[1.82359762e+03 1.29450373e+03 4.94876304e+02 2.52861401e+01
#   5.34530551e+01 2.21174665e+03 1.03852712e+04 4.30851267e+03
#   5.42050671e+02 1.28298808e+03 7.78658718e+01 1.40992548e+01
#   2.31520119e+01 8.92991505e+03 6.50372578e+01 9.97019374e-01
#   7.91356185e-01]
#  [1.04588585e+04 6.60376415e+03 2.58468868e+03 4.19433962e+01
#   7.06320755e+01 1.31202453e+04 1.07913491e+04 4.66779245e+03
#   5.95783019e+02 1.70560377e+03 9.13301887e+01 1.40292453e+01
#   2.01603774e+01 1.42828302e+04 6.79905660e+01 1.11022302e-16
#   3.20754717e-01]]
#                                         Private   Apps  Accept  Enroll  \
# Abilene Christian University                Yes   1660    1232     721
# Adelphi University                          Yes   2186    1924     512
# Adrian College                              Yes   1428    1097     336
# Agnes Scott College                         Yes    417     349     137
# Alaska Pacific University                   Yes    193     146      55
# ...

# %%
from sklearn.metrics import confusion_matrix
print("Removing P.Undergrad PhD")
print(confusion_matrix(df['Cluster_actual'],kmeans.labels_))
# Out:
# Removing P.Undergrad PhD
# [[140  72]
#  [531  34]]

# %%
#Removing P.Undergrad and PhD has a small impact but not a big different in the perforamance of the model.

# %%
#Overall, removing some columns increases the performance while removing some degrades the performance. Some columns doesn't have any impact on the model
